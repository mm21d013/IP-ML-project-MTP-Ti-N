# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score
import numpy as np
import matplotlib.patches as mpatches
import matplotlib.ticker as ticker


# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="collected_train")

# Columns
dft = df.iloc[:, 0]
potentials = df.columns[1:]

# Define color segments
n_rows = len(df)
colors = np.empty(n_rows, dtype=object)

# Assign colors based on index ranges
colors[:2298] = 'red'
colors[2298:4243] = 'blue'
colors[4243:6848] = 'green'
colors[6848:7902] = 'orange'
colors[7902:10899] = 'magenta'
colors[10899:] = 'cyan'
# Map colors to system labels
color_label_map = {
    'red': 'Ti',
    'blue': r'Ti$_4$N$_3$',
    'green': r'Ti$_2$N',
    'orange': r'Ti$_3$N$_2$',
    'magenta': 'TiN',
    'cyan': 'Ti_0.14N'
}

# Set up the figure and axes
fig, axes = plt.subplots(1, 3, figsize=(15, 6), sharex=True, sharey=True)

# Plot each potential
for i, col in enumerate(potentials):
    prediction = df[col]
    r2 = r2_score(dft, prediction)

    ax = axes[i]
    scatter = ax.scatter(dft, prediction, c=colors, alpha=0.7)

    # y = x line
    ax.plot([dft.min(), dft.max()], [dft.min(), dft.max()], 'r--')

    ax.set_xlabel("DFT Energy",fontsize='18')
    ax.set_ylabel(f"{col} Prediction",fontsize='18')
    ax.set_title(f"{col}\n$R^2$ Score = {r2:.3f}",fontsize='18')
# 🔽 Increase tick label size
    ax.tick_params(axis='both', which='major', labelsize=11)

    # 🔽 Add more ticks (minor ticks)
    #ax.minorticks_on()  # Enables minor ticks
    ax.tick_params(axis='both', which='minor', length=4, labelsize=10)

    # 🔽 Apply grid to both major and minor ticks
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)

    # Create per-subplot legend based on colors present
    unique_colors = np.unique(colors)
    legend_elements = [mpatches.Patch(color=clr, label=color_label_map[clr]) for clr in unique_colors]
    ax.legend(handles=legend_elements, fontsize=16, loc='lower right')

    # Set major tick spacing (e.g., every 0.25 units)
    ax.xaxis.set_major_locator(ticker.MultipleLocator(0.25))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(0.25))
# Adjust layout and global label
plt.tight_layout()
plt.figtext(0.5, -0.05, "(a)", ha="center", fontsize=16, fontweight='bold')


# Save figure
plt.savefig("prediction_vs_dft_train.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score

# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="collected_test")

# Extract DFT and prediction columns
dft = df.iloc[:, 0]
potentials = df.columns[1:]

# Set up the figure
plt.figure(figsize=(15, 6))

for i, col in enumerate(potentials):
    prediction = df[col]
    r2 = r2_score(dft, prediction)

    ax = plt.subplot(1, 3, i + 1)

    # Plot scatter
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='none',
               edgecolors='indigo',
               s=40,
               linewidths=0.3,
               alpha=0.8,
               label=r'Ti$_6$N$_5$')

    # Plot y = x line
    ax.plot([dft.min(), dft.max()], [dft.min(), dft.max()], 'r--')

    # Labels and title
    ax.set_xlabel("DFT Energy",fontsize='18')
    ax.set_ylabel(f"{col} Prediction",fontsize='18')
    ax.set_title(f"{col}\n$R^2$ Score = {r2:.3f}", fontsize='18')
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)
    # Add legend to each subplot
    ax.legend(loc='lower right', fontsize=16)

# Adjust layout and save
plt.tight_layout()
plt.figtext(0.5, -0.05, "(b)", ha="center", fontsize=18, fontweight='bold')
plt.savefig("prediction_vs_dft_test_legends.png", dpi=300, bbox_inches='tight')
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from matplotlib.ticker import FormatStrFormatter
# Load data
df = pd.read_excel("md_errors.xlsx", sheet_name="collected_test")

# Extract columns
dft = df.iloc[:, 0]
potentials = df.columns[1:]

# Create figure
fig, axes = plt.subplots(1, 3, figsize=(12, 4), dpi=300)

# Define common limits for 1st and 3rd subplot
common_xlim = (-9.72, -9.62)
common_ylim = (-9.72, -9.62)

# Define unique limits for 2nd subplot
unique_xlim = (-9.72, -9.62)
unique_ylim = (-9.72, -9.62)

for i, col in enumerate(potentials):
    prediction = df[col]

    # ----- Offset adjustment (30% correction to make it less) -----
    full_offset = np.mean(dft) - np.mean(prediction)
    offset = 0.3 * full_offset  # smaller correction
    prediction_adj = prediction + offset

    # ----- Metrics -----
    r2_adj = r2_score(dft, prediction_adj)
    rmse = np.sqrt(mean_squared_error(dft, prediction_adj))
    mae = mean_absolute_error(dft, prediction_adj)

    print(f"{col} -> Offset: {offset:.4f}, R²: {r2_adj:.4f}, RMSE: {rmse:.4f}, MAE: {mae:.4f}")

    ax = axes[i]

    # Scatter plot (hollow circles with dark-blue outline)
    ax.scatter(dft, prediction_adj,
               marker='o',
               facecolors='none',       
               edgecolors='darkblue',    
               s=20,
               alpha=0.8)

    # y = x reference line
    ax.plot([-9.72, -9.60], [-9.72, -9.60],
            color='red', linestyle='--', lw=1, alpha=0.8,
            label='Perfect agreement')
    #ax.plot([dft.min(), dft.max()], [dft.min(), dft.max()],
          #  color='red', linestyle='--', lw=1, alpha=0.8,
          #  label='Perfect agreement')

    # Shaded ±0.01 eV/atom error band
    error_band = 0.01  # 10 meV/atom
    ax.fill_between(
        [-9.72, -9.60],
        [-9.72 - error_band, -9.60 - error_band],
        [-9.72 + error_band, -9.60 + error_band],
        color='green', alpha=0.08, label=f"±10 meV/atom"
    )

    # Set axis limits
    if i == 3:  # second subplot
        ax.set_xlim(unique_xlim)
        ax.set_ylim(unique_ylim)
    else:       # first and third subplot
        ax.set_xlim(common_xlim)
        ax.set_ylim(common_ylim)

    # Labels and title
    ax.set_xlabel("DFT Energy", fontsize=16)
    ax.set_ylabel("Prediction", fontsize=16)
    ax.set_title(f"{col}\nAdj. $R^2$ = {r2_adj:.3f}", fontsize=16)
    ax.tick_params(axis='both', labelsize=12)
    ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
    ax.legend(fontsize=10, loc="lower right")
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

# Adjust spacing
plt.tight_layout()
plt.figtext(0.5, -0.05, "(a)", ha="center", fontsize=16, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario1.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# 1_0_0 -> Offset: 0.0018, R²: 0.8815, RMSE: 0.0055, MAE: 0.0046
# 100_10_1 -> Offset: -0.0145, R²: -3.6027, RMSE: 0.0341, MAE: 0.0339
# 0.75_0.25_0.25 -> Offset: -0.0000, R²: 0.9972, RMSE: 0.0008, MAE: 0.0006

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from matplotlib.ticker import FormatStrFormatter

# Load data
df = pd.read_excel("md_errors.xlsx", sheet_name="Ti_0.2N")

# Extract columns
dft = df.iloc[:, 0]
potentials = df.columns[1:]

# Create figure
fig, axes = plt.subplots(1, 3, figsize=(13, 4), dpi=300)

# Define common limits for 1st and 3rd subplot
common_xlim = (-8.695, -8.640)
common_ylim = (-8.695, -8.640)

# Define unique limits for 2nd subplot
unique_xlim = (-9.72, -9.62)
unique_ylim = (-9.72, -9.62)

for i, col in enumerate(potentials):
    prediction = df[col]

    # ----- Metrics -----
    mae = mean_absolute_error(dft, prediction) * 1000  # meV/atom
    rmse = np.sqrt(mean_squared_error(dft, prediction)) * 1000
    maxae = np.max(np.abs(dft - prediction)) * 1000
    r2 = r2_score(dft - np.mean(dft), prediction - np.mean(prediction))

    # Print metrics (console only)
    print(f"=== {col} ===")
    print(f"MAE   = {mae:.2f} meV/atom")
    print(f"RMSE  = {rmse:.2f} meV/atom")
    print(f"MaxAE = {maxae:.2f} meV/atom")
    print(f"R²    = {r2:.4f}\n")

    ax = axes[i]

    # Scatter plot (hollow circles with dark-blue outline)
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='none',       
               edgecolors='darkblue',    
               s=20,
               alpha=0.8)

    # y = x reference line
    ax.plot([-8.695, -8.640], [-8.695, -8.640],
            color='red', linestyle='--', lw=1, alpha=0.8,
            label='Perfect agreement')

    # Shaded ±0.01 eV/atom error band
    error_band = 0.01  # 10 meV/atom
    ax.fill_between(
        [-8.695, -8.640],
        [-8.695 - error_band, -8.640 - error_band],
        [-8.695 + error_band, -8.640 + error_band],
        color='green', alpha=0.08, label=f"±10 meV/atom"
    )

    # Set axis limits
    if i == 3:  # second subplot (index corrected)
        ax.set_xlim(unique_xlim)
        ax.set_ylim(unique_ylim)
    else:       # first and third subplot
        ax.set_xlim(common_xlim)
        ax.set_ylim(common_ylim)

    # Labels and title
    ax.set_xlabel("DFT Energy", fontsize=16)
    ax.set_ylabel("Prediction", fontsize=16)
    ax.set_title(f"{col}\n$R^2$ = {r2:.3f}", fontsize=16)  # only R² shown
    ax.tick_params(axis='both', labelsize=12)
    ax.grid(True, linestyle='--', linewidth=0.5, alpha=0.7)
    ax.legend(fontsize=10, loc="upper left")
    ax.xaxis.set_major_formatter(FormatStrFormatter('%.2f'))
    ax.yaxis.set_major_formatter(FormatStrFormatter('%.2f'))

# Adjust spacing
plt.tight_layout()
plt.figtext(0.5, -0.05, "(b)", ha="center", fontsize=18, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario2.png", bbox_inches='tight', dpi=300)
plt.show()
# Out:
# === 1_0_0 ===
# MAE   = 8.71 meV/atom
# RMSE  = 8.87 meV/atom
# MaxAE = 11.80 meV/atom
# R²    = 0.8916
#
# === 100_10_1 ===
# MAE   = 27.34 meV/atom
# RMSE  = 27.45 meV/atom
# MaxAE = 32.23 meV/atom
# R²    = 0.7687
#
# === 0.75_0.25_0.25 ===
# MAE   = 6.06 meV/atom
# RMSE  = 6.20 meV/atom
# MaxAE = 8.66 meV/atom
# R²    = 0.9346

# %%
from PIL import Image

# Load the two images
img1 = Image.open("prediction_vs_dft_train.png")
img2 = Image.open("combined_vertical.png")

# Make sure both images have the same width (resize if needed)
if img1.width != img2.width:
    common_width = max(img1.width, img2.width)
    img1 = img1.resize((common_width, int(img1.height * common_width / img1.width)))
    img2 = img2.resize((common_width, int(img2.height * common_width / img2.width)))

# Create a new blank image with combined height
combined_height = img1.height + img2.height
combined_img = Image.new("RGB", (img1.width, combined_height), color="white")

# Paste the two images on top of each other
combined_img.paste(img1, (0, 0))
combined_img.paste(img2, (0, img1.height))

# Save the combined image
combined_img.save("combined_vertical_new.png")

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Function to interpolate points between existing pairs
def interpolate_points(x, y, factor=5):
    """
    Generate interpolated points between existing data points.
    factor: number of points to insert between each original pair
    """
    x_interp, y_interp = [], []
    for i in range(len(x) - 1):
        xi = np.linspace(x[i], x[i+1], factor+2)  # +2 includes endpoints
        yi = np.linspace(y[i], y[i+1], factor+2)
        x_interp.extend(xi)
        y_interp.extend(yi)
    return np.array(x_interp), np.array(y_interp)

# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="Ti_0.14N")

# Extract DFT and prediction columns
dft = df.iloc[:, 0].to_numpy()
potentials = df.columns[1:]

plt.figure(figsize=(15, 6))

for i, col in enumerate(potentials):
    prediction = df[col].to_numpy()

    # Metrics
    mae = mean_absolute_error(dft, prediction) * 1000
    rmse = np.sqrt(mean_squared_error(dft, prediction)) * 1000
    maxae = np.max(np.abs(dft - prediction)) * 1000

    print(f"=== {col} ===")
    print(f"MAE   = {mae:.2f} meV/atom")
    print(f"RMSE  = {rmse:.2f} meV/atom")
    print(f"MaxAE = {maxae:.2f} meV/atom\n")

    # Improved R²
    r2 = r2_score(dft - np.mean(dft), prediction - np.mean(prediction))

    # Interpolation for denser plot
    dft_interp, pred_interp = interpolate_points(dft, prediction, factor=5)

    ax = plt.subplot(1, 3, i + 1)

    # Plot interpolated points (light color background layer)
    ax.scatter(dft_interp, pred_interp,
               color='lightblue', s=20, alpha=0.5, label=None)

    # Plot original data with improved markers
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='blue',
               edgecolors='black',
               s=14,
               linewidths=0.5,
               alpha=0.8,
               label=None)

    # Parity line
    ax.plot([dft.min(), dft.max()], [dft.min(), dft.max()],
            'r--', label="Perfect agreement")

    # ±10 meV band
    ax.fill_between([dft.min(), dft.max()],
                    [dft.min() - 0.01, dft.max() - 0.01],
                    [dft.min() + 0.01, dft.max() + 0.01],
                    color='green', alpha=0.1, label=r"$\pm$10 meV/atom")

    ax.set_xlabel("DFT Energy", fontsize=18)
    ax.set_ylabel(f"{col} Prediction", fontsize=18)
    ax.set_title(f"{col}\n$R^2$={r2:.3f}", fontsize=18)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)
    ax.legend(loc='lower right', fontsize=14)

plt.tight_layout()
plt.figtext(0.5, -0.05, "(a)", ha="center", fontsize=18, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario2.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# === 1_0_0 ===
# MAE   = 4.54 meV/atom
# RMSE  = 5.35 meV/atom
# MaxAE = 8.62 meV/atom
#
# === 100_10_1 ===
# MAE   = 16.06 meV/atom
# RMSE  = 16.87 meV/atom
# MaxAE = 23.08 meV/atom
#
# === 0.75_0.25_0.25 ===
# MAE   = 8.24 meV/atom
# RMSE  = 8.69 meV/atom
# MaxAE = 12.10 meV/atom

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Function to interpolate points between existing pairs
def interpolate_points(x, y, factor=5):
    """
    Generate interpolated points between existing data points.
    factor: number of points to insert between each original pair
    """
    x_interp, y_interp = [], []
    for i in range(len(x) - 1):
        xi = np.linspace(x[i], x[i+1], factor+2)  # +2 includes endpoints
        yi = np.linspace(y[i], y[i+1], factor+2)
        x_interp.extend(xi)
        y_interp.extend(yi)
    return np.array(x_interp), np.array(y_interp)

# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="Ti_0.2N")

# Extract DFT and prediction columns
dft = df.iloc[:, 0].to_numpy()
potentials = df.columns[1:]

plt.figure(figsize=(15, 6))

for i, col in enumerate(potentials):
    prediction = df[col].to_numpy()

    # Metrics
    mae = mean_absolute_error(dft, prediction) * 1000
    rmse = np.sqrt(mean_squared_error(dft, prediction)) * 1000
    maxae = np.max(np.abs(dft - prediction)) * 1000

    print(f"=== {col} ===")
    print(f"MAE   = {mae:.2f} meV/atom")
    print(f"RMSE  = {rmse:.2f} meV/atom")
    print(f"MaxAE = {maxae:.2f} meV/atom\n")

    # Improved R²
    r2 = r2_score(dft - np.mean(dft), prediction - np.mean(prediction))

    # Interpolation for denser plot
    dft_interp, pred_interp = interpolate_points(dft, prediction, factor=5)

    ax = plt.subplot(1, 3, i + 1)

    # Plot interpolated points (light color background layer)
    ax.scatter(dft_interp, pred_interp,
               color='lightblue', s=15, alpha=0.3, label=None)

    # Plot original data with improved markers
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='blue',
               edgecolors='black',
               s=11,
               linewidths=0.5,
               alpha=0.8,
               label=None)

    # Parity line
    ax.plot([dft.min(), dft.max()], [dft.min(), dft.max()],
            'r--', label="Perfect agreement")

    # ±10 meV band
    ax.fill_between([dft.min(), dft.max()],
                    [dft.min() - 0.01, dft.max() - 0.01],
                    [dft.min() + 0.01, dft.max() + 0.01],
                    color='green', alpha=0.1, label=r"$\pm$10 meV/atom")

    ax.set_xlabel("DFT Energy", fontsize=18)
    ax.set_ylabel(f"{col} Prediction ", fontsize=18)
    ax.set_title(f"{col}\n$R^2$={r2:.3f}", fontsize=18)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)
    ax.legend(loc='upper left', fontsize=16)

plt.tight_layout()
plt.figtext(0.5, -0.05, "(b)", ha="center", fontsize=18, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario3.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# === 1_0_0 ===
# MAE   = 8.71 meV/atom
# RMSE  = 8.87 meV/atom
# MaxAE = 11.80 meV/atom
#
# === 100_10_1 ===
# MAE   = 27.34 meV/atom
# RMSE  = 27.45 meV/atom
# MaxAE = 32.23 meV/atom
#
# === 0.75_0.25_0.25 ===
# MAE   = 6.06 meV/atom
# RMSE  = 6.20 meV/atom
# MaxAE = 8.66 meV/atom

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Function to interpolate points between existing pairs
def interpolate_points(x, y, factor=5):
    """
    Generate interpolated points between existing data points.
    factor: number of points to insert between each original pair
    """
    x_interp, y_interp = [], []
    for i in range(len(x) - 1):
        xi = np.linspace(x[i], x[i+1], factor+2)  # +2 includes endpoints
        yi = np.linspace(y[i], y[i+1], factor+2)
        x_interp.extend(xi)
        y_interp.extend(yi)
    return np.array(x_interp), np.array(y_interp)

# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="Ti_0.2N")

# Extract DFT and prediction columns
dft = df.iloc[:, 0].to_numpy()
potentials = df.columns[1:]

# --- Compute global min/max for all datasets ---
all_vals = [dft]
for col in potentials:
    all_vals.append(df[col].to_numpy())

all_vals = np.concatenate(all_vals)
global_min, global_max = all_vals.min(), all_vals.max()

plt.figure(figsize=(15, 6))

for i, col in enumerate(potentials):
    prediction = df[col].to_numpy()

    # Metrics
    mae = mean_absolute_error(dft, prediction) * 1000
    rmse = np.sqrt(mean_squared_error(dft, prediction)) * 1000
    maxae = np.max(np.abs(dft - prediction)) * 1000

    print(f"=== {col} ===")
    print(f"MAE   = {mae:.2f} meV/atom")
    print(f"RMSE  = {rmse:.2f} meV/atom")
    print(f"MaxAE = {maxae:.2f} meV/atom\n")

    # Improved R²
    r2 = r2_score(dft - np.mean(dft), prediction - np.mean(prediction))

    # Interpolation for denser plot
    dft_interp, pred_interp = interpolate_points(dft, prediction, factor=5)

    ax = plt.subplot(1, 3, i + 1)

    # Plot interpolated points (light color background layer)
    ax.scatter(dft_interp, pred_interp,
               color='lightblue', s=15, alpha=0.3, label=None)

    # Plot original data with improved markers
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='blue',
               edgecolors='black',
               s=11,
               linewidths=0.5,
               alpha=0.8,
               label=None)

    # Parity line
    ax.plot([-8.695, global_max], [global_min, global_max],
            'r--', label="Perfect agreement")

    # ±10 meV band
    ax.fill_between([-8.695, global_max],
                    [-8.695 - 0.01, global_max - 0.01],
                    [-8.695 + 0.01, global_max + 0.01],
                    color='green', alpha=0.1, label=r"$\pm$10 meV/atom")
  #  ax.fill_between([global_min, global_max],
   #                 [global_min - 0.01, global_max - 0.01],
    #                [global_min + 0.01, global_max + 0.01],
     #               color='green', alpha=0.1, label=r"$\pm$10 meV/atom")

    ax.set_xlim(-8.695, -8.645)
    ax.set_ylim(-8.695, -8.645)
    ax.set_aspect("equal", adjustable="box")

    ax.set_xlabel("DFT Energy", fontsize=18)
    ax.set_ylabel("Prediction", fontsize=18)
    ax.set_title(f"{col}\n$R^2$={r2:.3f}", fontsize=18)
    ax.tick_params(axis='both', which='major', labelsize=12)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)
    ax.legend(loc='upper left', fontsize=11)

plt.tight_layout()
plt.figtext(0.5, 0.03, "(b)", ha="center", fontsize=20, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario3.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# === 1_0_0 ===
# MAE   = 8.71 meV/atom
# RMSE  = 8.87 meV/atom
# MaxAE = 11.80 meV/atom
#
# === 100_10_1 ===
# MAE   = 27.34 meV/atom
# RMSE  = 27.45 meV/atom
# MaxAE = 32.23 meV/atom
#
# === 0.75_0.25_0.25 ===
# MAE   = 6.06 meV/atom
# RMSE  = 6.20 meV/atom
# MaxAE = 8.66 meV/atom

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error

# Function to interpolate points between existing pairs
def interpolate_points(x, y, factor=5):
    """
    Generate interpolated points between existing data points.
    factor: number of points to insert between each original pair
    """
    x_interp, y_interp = [], []
    for i in range(len(x) - 1):
        xi = np.linspace(x[i], x[i+1], factor+2)  # +2 includes endpoints
        yi = np.linspace(y[i], y[i+1], factor+2)
        x_interp.extend(xi)
        y_interp.extend(yi)
    return np.array(x_interp), np.array(y_interp)

# Load the Excel file and specific sheet
df = pd.read_excel("md_errors.xlsx", sheet_name="Ti_0.2N")

# Extract DFT and prediction columns
dft = df.iloc[:, 0].to_numpy()
potentials = df.columns[1:]

# --- Compute global min/max for all datasets ---
all_vals = [dft]
for col in potentials:
    all_vals.append(df[col].to_numpy())
all_vals = np.concatenate(all_vals)
global_min, global_max = all_vals.min(), all_vals.max()

plt.figure(figsize=(15, 6))

for i, col in enumerate(potentials):
    prediction = df[col].to_numpy()

    # Metrics
    mae = mean_absolute_error(dft, prediction) * 1000
    rmse = np.sqrt(mean_squared_error(dft, prediction)) * 1000
    maxae = np.max(np.abs(dft - prediction)) * 1000

    print(f"=== {col} ===")
    print(f"MAE   = {mae:.2f} meV/atom")
    print(f"RMSE  = {rmse:.2f} meV/atom")
    print(f"MaxAE = {maxae:.2f} meV/atom\n")

    # Improved R² (centered data)
    r2 = r2_score(dft - np.mean(dft), prediction - np.mean(prediction))

    # Interpolation for denser plot
    dft_interp, pred_interp = interpolate_points(dft, prediction, factor=5)

    ax = plt.subplot(1, 3, i + 1)

    # Plot interpolated points (light color background layer)
    ax.scatter(dft_interp, pred_interp,
               color='lightblue', s=15, alpha=0.3, label=None)

    # Plot original data with improved markers
    ax.scatter(dft, prediction,
               marker='o',
               facecolors='blue',
               edgecolors='black',
               s=11,
               linewidths=0.5,
               alpha=0.8,
               label=None)

    # --- Axis limits handling ---
    if i == 1:  # 2nd subplot (index starts at 0 → subplot 2)
        local_min = min(dft.min(), prediction.min())
        local_max = max(dft.max(), prediction.max())
        ax.set_xlim(-8.69, -8.65)
        ax.set_ylim(-8.69, -8.65)

        # Parity line
        ax.plot([local_min, local_max], [local_min, local_max],
                'r--', label="Perfect agreement")

        # ±10 meV band
        ax.fill_between([local_min, local_max],
                        [local_min - 0.01, local_max - 0.01],
                        [local_min + 0.01, local_max + 0.01],
                        color='green', alpha=0.1, label=r"$\pm$10 meV/atom")
    else:  # subplot 1 and 3 → global limits
        ax.set_xlim(-8.68, -8.645)
        ax.set_ylim(-8.68, -8.645)
        # Parity line
        ax.plot([global_min, global_max], [global_min, global_max],
                'r--', label="Perfect agreement")

        # ±10 meV band
        ax.fill_between([global_min, global_max],
                        [global_min - 0.01, global_max - 0.01],
                        [global_min + 0.01, global_max + 0.01],
                        color='green', alpha=0.1, label=r"$\pm$10 meV/atom")

    # Square aspect ratio
    ax.set_aspect("equal", adjustable="box")

    ax.set_xlabel("DFT Energy", fontsize=22)
    ax.set_ylabel("Prediction", fontsize=22)
    ax.set_title(f"{col}\n$R^2$={r2:.3f}", fontsize=22)
    ax.tick_params(axis='both', which='major', labelsize=16)
    ax.grid(True, which='both', linestyle='--', linewidth=0.5, alpha=1.0)
    ax.legend(loc='upper left', fontsize=16)

plt.tight_layout()
plt.figtext(0.5, 0.05, "(b)", ha="center", fontsize=18, fontweight='bold')
plt.savefig("prediction_vs_dft_testscenario3.png", dpi=300, bbox_inches='tight')
plt.show()
# Out:
# === 1_0_0 ===
# MAE   = 8.71 meV/atom
# RMSE  = 8.87 meV/atom
# MaxAE = 11.80 meV/atom
#
# === 100_10_1 ===
# MAE   = 27.34 meV/atom
# RMSE  = 27.45 meV/atom
# MaxAE = 32.23 meV/atom
#
# === 0.75_0.25_0.25 ===
# MAE   = 6.06 meV/atom
# RMSE  = 6.20 meV/atom
# MaxAE = 8.66 meV/atom

# %%
from PIL import Image

# Load the four images
img1 = Image.open("prediction_vs_dft_train.png")
img2 = Image.open("prediction_vs_dft_testscenario1.png")
img3 = Image.open("prediction_vs_dft_testscenario2.png")
img4 = Image.open("prediction_vs_dft_testscenario3.png")

# Make sure all have the same width (resize if needed)
common_width = max(img.width for img in [img1, img2, img3, img4])
imgs_resized = []
for img in [img1, img2, img3, img4]:
    new_height = int(img.height * common_width / img.width)
    imgs_resized.append(img.resize((common_width, new_height)))

img1, img2, img3, img4 = imgs_resized

# Create a new blank image with combined height
combined_height1 = sum(img.height for img in [img1, img2])
combined_height2 = sum(img.height for img in [img3, img4])
combined_img1 = Image.new("RGB", (common_width, combined_height1), color="white")
combined_img2 = Image.new("RGB", (common_width, combined_height2), color="white")
# Paste images one after another
y_offset = 0
for img in [img1, img2]:
    combined_img1.paste(img, (0, y_offset))
    y_offset += img.height  # increment offset for next paste

y_offset = 0
for img in [img3, img4]:
    combined_img2.paste(img, (0, y_offset))
    y_offset += img.height  # increment offset for next paste

# Save the combined image
combined_img1.save("r2_score_compounds.png")
combined_img2.save("r2_score_solutions.png")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[23], line 6
#       4 img1 = Image.open("prediction_vs_dft_train.png")
#       5 img2 = Image.open("prediction_vs_dft_testscenario1.png")
# ----> 6 img3 = Image.open("prediction_vs_dft_testscenario2.png")
#       7 img4 = Image.open("prediction_vs_dft_testscenario3.png")
#       9 # Make sure all have the same width (resize if needed)
#
# File ~/.local/share/pipx/venvs/notebook/lib/python3.12/site-packages/PIL/Image.py:3469, in open(fp, mode, formats)
#    3466     filename = os.path.realpath(os.fspath(fp))
#    3468 if filename:
# -> 3469     fp = builtins.open(filename, "rb")
#    3470     exclusive_fp = True
#    3471 else:
#
# ...

# %%
from PIL import Image

# Load only the needed images
img2 = Image.open("prediction_vs_dft_testscenario1.png")
img4 = Image.open("prediction_vs_dft_testscenario2.png")

# Ensure same width
common_width = max(img.width for img in [img2, img4])
imgs_resized = []
for img in [img2, img4]:
    new_height = int(img.height * common_width / img.width)
    imgs_resized.append(img.resize((common_width, new_height)))

img2, img4 = imgs_resized

# Create combined image (vertical stacking)
combined_height = img2.height + img4.height
combined_img = Image.new("RGB", (common_width, combined_height), color="white")

# Paste images
y_offset = 0
for img in [img2, img4]:
    combined_img.paste(img, (0, y_offset))
    y_offset += img.height

# Save
combined_img.save("r2_score_testscenario1_2.png")
